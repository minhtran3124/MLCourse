# %% [markdown]
# # Try creating a scatter plot representing random data on age vs. time spent watching TV. Label the axes.

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# %%
from pylab import randn

ages = randn(500)
watching_hours = randn(500)

axes = plt.axes()
# axes.set_xlim(ages)
# axes.set_ylim(watching_hours)
# axes.grid()

plt.xlabel('Age')
plt.ylabel('Hours')
plt.scatter(ages, watching_hours)
plt.show()
